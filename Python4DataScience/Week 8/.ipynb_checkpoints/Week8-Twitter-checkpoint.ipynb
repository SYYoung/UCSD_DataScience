# %% [markdown]
# # Twitter data
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Twitter API Access
#
# Twitter implements OAuth 1.0A as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application.
#
# Choose any name for your application, write a description and use `http://google.com` for the website.
#
# Under **Key and Access Tokens**, there are four primary identifiers you'll need to note for an OAuth 1.0A workflow:
# * consumer key,
# * consumer secret,
# * access token, and
# * access token secret (Click on Create Access Token to create those).
#
# Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.

# %% [markdown]
# The first time you execute the notebook, add all credentials so that you can save them in the `pkl` file, then you can remove the secret keys from the notebook because they will just be loaded from the `pkl` file.
#
# The `pkl` file contains sensitive information that can be used to take control of your twitter acccount, **do not share it**.

# %%
import pickle
import os

# %%
if not os.path.exists('secret_twitter_credentials.pkl'):
    Twitter={}
    Twitter['Consumer Key'] = ''
    Twitter['Consumer Secret'] = ''
    Twitter['Access Token'] = ''
    Twitter['Access Token Secret'] = ''
    with open('secret_twitter_credentials.pkl','wb') as f:
        pickle.dump(Twitter, f)
else:
    Twitter=pickle.load(open('secret_twitter_credentials.pkl','rb'))

# %% [markdown]
# Install the `twitter` package to interface with the Twitter API

# %%
# !pip install twitter
# Out:
# Requirement already satisfied: twitter in /Users/r38411/anaconda2/envs/py35/lib/python3.5/site-packages
# You are using pip version 9.0.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# ## Example 1. Authorizing an application to access Twitter account data

# %%
import twitter

auth = twitter.oauth.OAuth(Twitter['Access Token'],
                           Twitter['Access Token Secret'],
                           Twitter['Consumer Key'],
                           Twitter['Consumer Secret'])

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x103f9b4a8>

# %% [markdown]
# ## Example 2. Retrieving trends

# %% [markdown]
# Twitter identifies locations using the Yahoo! Where On Earth ID.
#
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/
#
# look at the BOSS placefinder here: https://developer.yahoo.com/boss/placefinder/

# %%
WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# %% [markdown]
# Look for the WOEID for [san-diego](http://woeid.rosselliot.co.nz/lookup/san%20diego%20%20ca)
#
# You can change it to another location.

# %%
#help(twitter_api.trends.place)

# %%
LOCAL_WOE_ID=2487889

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)
local_trends = twitter_api.trends.place(_id=LOCAL_WOE_ID)

# %%
type(world_trends)
vars(world_trends)
len(world_trends[0]['trends'])
world_trends[0]['trends'][0]
# Out:
# {'name': '#20MillionReasons',
#  'promoted_content': None,
#  'query': '%2320MillionReasons',
#  'tweet_volume': 29913,
#  'url': 'http://twitter.com/search?q=%2320MillionReasons'}

# %%
world_trends[:2]
# Out:
# [{'as_of': '2019-05-24T06:08:34Z',
#   'created_at': '2019-05-24T06:01:53Z',
#   'locations': [{'name': 'Worldwide', 'woeid': 1}],
#   'trends': [{'name': '#20MillionReasons',
#     'promoted_content': None,
#     'query': '%2320MillionReasons',
#     'tweet_volume': 29913,
#     'url': 'http://twitter.com/search?q=%2320MillionReasons'},
#    {'name': '#MeTeníaChato',
#     'promoted_content': None,
#     'query': '%23MeTen%C3%ADaChato',
#     'tweet_volume': 34663,
#     'url': 'http://twitter.com/search?q=%23MeTen%C3%ADaChato'},
#    {'name': '#LoveBTS20M',
#     'promoted_content': None,
#     'query': '%23LoveBTS20M',
#     'tweet_volume': 23221,
#     'url': 'http://twitter.com/search?q=%23LoveBTS20M'},
#    {'name': '#PhasesEP',
#     'promoted_content': None,
#     'query': '%23PhasesEP',
#     'tweet_volume': 10011,
#     'url': 'http://twitter.com/search?q=%23PhasesEP'},
#    {'name': '#yağmur',
#     'promoted_content': None,
#     'query': '%23ya%C4%9Fmur',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23ya%C4%9Fmur'},
#    {'name': '適応障害',
#     'promoted_content': None,
#     'query': '%E9%81%A9%E5%BF%9C%E9%9A%9C%E5%AE%B3',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%E9%81%A9%E5%BF%9C%E9%9A%9C%E5%AE%B3'},
#    {'name': 'João Pedro',
#     'promoted_content': None,
#     'query': '%22Jo%C3%A3o+Pedro%22',
#     'tweet_volume': 41805,
#     'url': 'http://twitter.com/search?q=%22Jo%C3%A3o+Pedro%22'},
#    {'name': 'ヴィエラ',
#     'promoted_content': None,
#     'query': '%E3%83%B4%E3%82%A3%E3%82%A8%E3%83%A9',
#     'tweet_volume': 13436,
#     'url': 'http://twitter.com/search?q=%E3%83%B4%E3%82%A3%E3%82%A8%E3%83%A9'},
#    {'name': 'ベンチマーク',
#     'promoted_content': None,
#     'query': '%E3%83%99%E3%83%B3%E3%83%81%E3%83%9E%E3%83%BC%E3%82%AF',
#     'tweet_volume': 20825,
#     'url': 'http://twitter.com/search?q=%E3%83%99%E3%83%B3%E3%83%81%E3%83%9E%E3%83%BC%E3%82%AF'},
#    {'name': 'Aaron Rodgers',
#     'promoted_content': None,
#     'query': '%22Aaron+Rodgers%22',
#     'tweet_volume': 34734,
#     'url': 'http://twitter.com/search?q=%22Aaron+Rodgers%22'},
#    {'name': 'Bucks in 7',
#     'promoted_content': None,
#     'query': '%22Bucks+in+7%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Bucks+in+7%22'},
#    {'name': 'ロスガル',
#     'promoted_content': None,
#     'query': '%E3%83%AD%E3%82%B9%E3%82%AC%E3%83%AB',
#     'tweet_volume': 11169,
#     'url': 'http://twitter.com/search?q=%E3%83%AD%E3%82%B9%E3%82%AC%E3%83%AB'},
#    {'name': 'Gignac',
#     'promoted_content': None,
#     'query': 'Gignac',
#     'tweet_volume': 10223,
#     'url': 'http://twitter.com/search?q=Gignac'},
#    {'name': 'Fred VanVleet',
#     'promoted_content': None,
#     'query': '%22Fred+VanVleet%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Fred+VanVleet%22'},
#    {'name': '#FikrimYok',
#     'promoted_content': None,
#     'query': '%23FikrimYok',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23FikrimYok'},
#    {'name': '#يوم_الجمعه',
#     'promoted_content': None,
#     'query': '%23%D9%8A%D9%88%D9%85_%D8%A7%D9%84%D8%AC%D9%85%D8%B9%D9%87',
#     'tweet_volume': 36736,
#     'url': 'http://twitter.com/search?q=%23%D9%8A%D9%88%D9%85_%D8%A7%D9%84%D8%AC%D9%85%D8%B9%D9%87'},
#    {'name': '#HayırlıCumalar',
#     'promoted_content': None,
#     'query': '%23Hay%C4%B1rl%C4%B1Cumalar',
#     'tweet_volume': 11126,
#     'url': 'http://twitter.com/search?q=%23Hay%C4%B1rl%C4%B1Cumalar'},
#    {'name': '#PactoDeSangre',
#     'promoted_content': None,
#     'query': '%23PactoDeSangre',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23PactoDeSangre'},
#    {'name': '#BTS20M',
#     'promoted_content': None,
#     'query': '%23BTS20M',
#     'tweet_volume': 11383,
#     'url': 'http://twitter.com/search?q=%23BTS20M'},
#    {'name': '#ทฤษฎีจีบเธอ',
#     'promoted_content': None,
#     'query': '%23%E0%B8%97%E0%B8%A4%E0%B8%A9%E0%B8%8E%E0%B8%B5%E0%B8%88%E0%B8%B5%E0%B8%9A%E0%B9%80%E0%B8%98%E0%B8%AD',
#     'tweet_volume': 170063,
#     'url': 'http://twitter.com/search?q=%23%E0%B8%97%E0%B8%A4%E0%B8%A9%E0%B8%8E%E0%B8%B5%E0%B8%88%E0%B8%B5%E0%B8%9A%E0%B9%80%E0%B8%98%E0%B8%AD'},
#    {'name': '#TNRejectsBJP',
#     'promoted_content': None,
#     'query': '%23TNRejectsBJP',
#     'tweet_volume': 17435,
#     'url': 'http://twitter.com/search?q=%23TNRejectsBJP'},
#    {'name': '#HampaDelPeriodismo',
#     'promoted_content': None,
#     'query': '%23HampaDelPeriodismo',
#     'tweet_volume': 12303,
#     'url': 'http://twitter.com/search?q=%23HampaDelPeriodismo'},
#    {'name': '#İtirazımızVar',
#     'promoted_content': None,
#     'query': '%23%C4%B0tiraz%C4%B1m%C4%B1zVar',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23%C4%B0tiraz%C4%B1m%C4%B1zVar'},
#    {'name': '#ProtestoEdiyorum',
#     'promoted_content': None,
#     'query': '%23ProtestoEdiyorum',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23ProtestoEdiyorum'},
#    {'name': '#KemenanganUntukSemua',
#     'promoted_content': None,
#     'query': '%23KemenanganUntukSemua',
#     'tweet_volume': 13272,
#     'url': 'http://twitter.com/search?q=%23KemenanganUntukSemua'},
#    {'name': '#TORvsMIL',
#     'promoted_content': None,
#     'query': '%23TORvsMIL',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23TORvsMIL'},
#    {'name': '#mykpopcareer',
#     'promoted_content': None,
#     'query': '%23mykpopcareer',
#     'tweet_volume': 15235,
#     'url': 'http://twitter.com/search?q=%23mykpopcareer'},
#    {'name': '#اختيار_التخصص_الجامعي',
#     'promoted_content': None,
#     'query': '%23%D8%A7%D8%AE%D8%AA%D9%8A%D8%A7%D8%B1_%D8%A7%D9%84%D8%AA%D8%AE%D8%B5%D8%B5_%D8%A7%D9%84%D8%AC%D8%A7%D9%85%D8%B9%D9%8A',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23%D8%A7%D8%AE%D8%AA%D9%8A%D8%A7%D8%B1_%D8%A7%D9%84%D8%AA%D8%AE%D8%B5%D8%B5_%D8%A7%D9%84%D8%AC%D8%A7%D9%85%D8%B9%D9%8A'},
#    {'name': '#LaPiñaDeLaDiscordia',
#     'promoted_content': None,
#     'query': '%23LaPi%C3%B1aDeLaDiscordia',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23LaPi%C3%B1aDeLaDiscordia'},
#    {'name': '#あなたの中身は何か',
#     'promoted_content': None,
#     'query': '%23%E3%81%82%E3%81%AA%E3%81%9F%E3%81%AE%E4%B8%AD%E8%BA%AB%E3%81%AF%E4%BD%95%E3%81%8B',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23%E3%81%82%E3%81%AA%E3%81%9F%E3%81%AE%E4%B8%AD%E8%BA%AB%E3%81%AF%E4%BD%95%E3%81%8B'},
#    {'name': '#ياعلي',
#     'promoted_content': None,
#     'query': '%23%D9%8A%D8%A7%D8%B9%D9%84%D9%8A',
#     'tweet_volume': 15491,
#     'url': 'http://twitter.com/search?q=%23%D9%8A%D8%A7%D8%B9%D9%84%D9%8A'},
#    {'name': '#PromediosEnTyCSports',
#     'promoted_content': None,
#     'query': '%23PromediosEnTyCSports',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23PromediosEnTyCSports'},
#    {'name': '#LipsDontLie',
#     'promoted_content': None,
#     'query': '%23LipsDontLie',
#     'tweet_volume': 13133,
#     'url': 'http://twitter.com/search?q=%23LipsDontLie'},
#    {'name': '#THRBelumTerlihat',
#     'promoted_content': None,
#     'query': '%23THRBelumTerlihat',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23THRBelumTerlihat'},
#    {'name': '#YoSoyAnimal',
#     'promoted_content': None,
#     'query': '%23YoSoyAnimal',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23YoSoyAnimal'},
#    {'name': '#RaptorsVsBucks',
#     'promoted_content': None,
#     'query': '%23RaptorsVsBucks',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23RaptorsVsBucks'},
#    {'name': '#ExNaMTV',
#     'promoted_content': None,
#     'query': '%23ExNaMTV',
#     'tweet_volume': 15331,
#     'url': 'http://twitter.com/search?q=%23ExNaMTV'},
#    {'name': '#مسابقه_المربع_نت١٩',
#     'promoted_content': None,
#     'query': '%23%D9%85%D8%B3%D8%A7%D8%A8%D9%82%D9%87_%D8%A7%D9%84%D9%85%D8%B1%D8%A8%D8%B9_%D9%86%D8%AA%D9%A1%D9%A9',
#     'tweet_volume': 15500,
#     'url': 'http://twitter.com/search?q=%23%D9%85%D8%B3%D8%A7%D8%A8%D9%82%D9%87_%D8%A7%D9%84%D9%85%D8%B1%D8%A8%D8%B9_%D9%86%D8%AA%D9%A1%D9%A9'},
#    {'name': '#PowerCoupleMulheres',
#     'promoted_content': None,
#     'query': '%23PowerCoupleMulheres',
#     'tweet_volume': 12082,
#     'url': 'http://twitter.com/search?q=%23PowerCoupleMulheres'},
#    {'name': '#ShowtimeMaCOOLay',
#     'promoted_content': None,
#     'query': '%23ShowtimeMaCOOLay',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23ShowtimeMaCOOLay'},
#    {'name': '#mybtsenergy',
#     'promoted_content': None,
#     'query': '%23mybtsenergy',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23mybtsenergy'},
#    {'name': '#CongratulationsMheshimiwa',
#     'promoted_content': None,
#     'query': '%23CongratulationsMheshimiwa',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23CongratulationsMheshimiwa'},
#    {'name': '#WeirdQuestionsForGoogle',
#     'promoted_content': None,
#     'query': '%23WeirdQuestionsForGoogle',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23WeirdQuestionsForGoogle'},
#    {'name': '#JumatBerkah',
#     'promoted_content': None,
#     'query': '%23JumatBerkah',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23JumatBerkah'},
#    {'name': '#SextaDetremuraSDV',
#     'promoted_content': None,
#     'query': '%23SextaDetremuraSDV',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23SextaDetremuraSDV'},
#    {'name': '#SaanNapupuntaAngPeraMo',
#     'promoted_content': None,
#     'query': '%23SaanNapupuntaAngPeraMo',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23SaanNapupuntaAngPeraMo'},
#    {'name': '#LosCruzados',
#     'promoted_content': None,
#     'query': '%23LosCruzados',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23LosCruzados'},
#    {'name': '#WeTheNorh',
#     'promoted_content': None,
#     'query': '%23WeTheNorh',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23WeTheNorh'},
#    {'name': '#ChatpataElection',
#     'promoted_content': None,
#     'query': '%23ChatpataElection',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23ChatpataElection'},
#    {'name': '#자캐는_체육대회에서_무슨_종목',
#     'promoted_content': None,
#     'query': '%23%EC%9E%90%EC%BA%90%EB%8A%94_%EC%B2%B4%EC%9C%A1%EB%8C%80%ED%9A%8C%EC%97%90%EC%84%9C_%EB%AC%B4%EC%8A%A8_%EC%A2%85%EB%AA%A9',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23%EC%9E%90%EC%BA%90%EB%8A%94_%EC%B2%B4%EC%9C%A1%EB%8C%80%ED%9A%8C%EC%97%90%EC%84%9C_%EB%AC%B4%EC%8A%A8_%EC%A2%85%EB%AA%A9'}]}]

# %%
trends=local_trends
print(type(trends))
print(list(trends[0].keys()))
#print(trends[0]['trends'])
# Out:
# <class 'twitter.api.TwitterListResponse'>
# ['trends', 'locations', 'created_at', 'as_of']

# %% [markdown]
# ## Example 3. Displaying API responses as pretty-printed JSON

# %%
import json

print((json.dumps(us_trends[:2], indent=1)))
# Out:
# [
#  {
#   "trends": [
#    {
#     "tweet_volume": 10011,
#     "query": "%23PhasesEP",
#     "url": "http://twitter.com/search?q=%23PhasesEP",
#     "name": "#PhasesEP",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": 29913,
#     "query": "%2320MillionReasons",
#     "url": "http://twitter.com/search?q=%2320MillionReasons",
#     "name": "#20MillionReasons",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": 34734,
#     "query": "%22Aaron+Rodgers%22",
#     "url": "http://twitter.com/search?q=%22Aaron+Rodgers%22",
#     "name": "Aaron Rodgers",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": 23221,
#     "query": "%23LoveBTS20M",
#     "url": "http://twitter.com/search?q=%23LoveBTS20M",
#     "name": "#LoveBTS20M",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": null,
#     "query": "%23TORvsMIL",
#     "url": "http://twitter.com/search?q=%23TORvsMIL",
#     "name": "#TORvsMIL",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": null,
#     "query": "%23WeirdQuestionsForGoogle",
#     "url": "http://twitter.com/search?q=%23WeirdQuestionsForGoogle",
#     "name": "#WeirdQuestionsForGoogle",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": null,
#     "query": "%22Bucks+in+7%22",
#     "url": "http://twitter.com/search?q=%22Bucks+in+7%22",
#     "name": "Bucks in 7",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": null,
#     "query": "%22Steve+Lacy%22",
#     "url": "http://twitter.com/search?q=%22Steve+Lacy%22",
#     "name": "Steve Lacy",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": 18379,
#     "query": "Krassensteins",
#     "url": "http://twitter.com/search?q=Krassensteins",
#     "name": "Krassensteins",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": null,
#     "query": "%22Fred+VanVleet%22",
#     "url": "http://twitter.com/search?q=%22Fred+VanVleet%22",
#     "name": "Fred VanVleet",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": null,
#     "query": "%22Beast+Coast%22",
#     "url": "http://twitter.com/search?q=%22Beast+Coast%22",
#     "name": "Beast Coast",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": 15633,
#     "query": "%22Pusha+T%22",
#     "url": "http://twitter.com/search?q=%22Pusha+T%22",
#     "name": "Pusha T",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": 10255,
#     "query": "Viera",
#     "url": "http://twitter.com/search?q=Viera",
#     "name": "Viera",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": null,
#     "query": "%22Mallory+Edens%22",
#     "url": "http://twitter.com/search?q=%22Mallory+Edens%22",
#     "name": "Mallory Edens",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": null,
#     "query": "%22Lucas+Giolito%22",
#     "url": "http://twitter.com/search?q=%22Lucas+Giolito%22",
#     "name": "Lucas Giolito",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": null,
#     "query": "%22Money+Man%22",
#     "url": "http://twitter.com/search?q=%22Money+Man%22",
#     "name": "Money Man",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": null,
#     "query": "%22Chris+Webber%22",
#     "url": "http://twitter.com/search?q=%22Chris+Webber%22",
#     "name": "Chris Webber",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": null,
#     "query": "%22Eyes+Off+You%22",
#     "url": "http://twitter.com/search?q=%22Eyes+Off+You%22",
#     "name": "Eyes Off You",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": null,
#     "query": "%22Raptors+in+6%22",
#     "url": "http://twitter.com/search?q=%22Raptors+in+6%22",
#     "name": "Raptors in 6",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": 31297,
#     "query": "%22The+London%22",
#     "url": "http://twitter.com/search?q=%22The+London%22",
#     "name": "The London",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": null,
#     "query": "%22Marv+Albert%22",
#     "url": "http://twitter.com/search?q=%22Marv+Albert%22",
#     "name": "Marv Albert",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": null,
#     "query": "%22Gucci+Mane%22",
#     "url": "http://twitter.com/search?q=%22Gucci+Mane%22",
#     "name": "Gucci Mane",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": null,
#     "query": "%22Ross+Bjork%22",
#     "url": "http://twitter.com/search?q=%22Ross+Bjork%22",
#     "name": "Ross Bjork",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": null,
#     "query": "%22Van+Vleet%22",
#     "url": "http://twitter.com/search?q=%22Van+Vleet%22",
#     "name": "Van Vleet",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": null,
#     "query": "Moneybagg",
#     "url": "http://twitter.com/search?q=Moneybagg",
#     "name": "Moneybagg",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": 12829,
#     "query": "Dionne",
#     "url": "http://twitter.com/search?q=Dionne",
#     "name": "Dionne",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": 12061,
#     "query": "%23CriticalRole",
#     "url": "http://twitter.com/search?q=%23CriticalRole",
#     "name": "#CriticalRole",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": null,
#     "query": "%234REAL4REAL",
#     "url": "http://twitter.com/search?q=%234REAL4REAL",
#     "name": "#4REAL4REAL",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": null,
#     "query": "%23mybtsenergy",
#     "url": "http://twitter.com/search?q=%23mybtsenergy",
#     "name": "#mybtsenergy",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": null,
#     "query": "%23ProjectRunway",
#     "url": "http://twitter.com/search?q=%23ProjectRunway",
#     "name": "#ProjectRunway",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": null,
#     "query": "%23WhenIAmOutWithFriends",
#     "url": "http://twitter.com/search?q=%23WhenIAmOutWithFriends",
#     "name": "#WhenIAmOutWithFriends",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": null,
#     "query": "%23UnlikelyReasonsToMoveOut",
#     "url": "http://twitter.com/search?q=%23UnlikelyReasonsToMoveOut",
#     "name": "#UnlikelyReasonsToMoveOut",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": 27453,
#     "query": "%23StableGenius",
#     "url": "http://twitter.com/search?q=%23StableGenius",
#     "name": "#StableGenius",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": null,
#     "query": "%2343VAHEARTLESS",
#     "url": "http://twitter.com/search?q=%2343VAHEARTLESS",
#     "name": "#43VAHEARTLESS",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": null,
#     "query": "%23EscapeFromNewYork",
#     "url": "http://twitter.com/search?q=%23EscapeFromNewYork",
#     "name": "#EscapeFromNewYork",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": null,
#     "query": "%23starlink",
#     "url": "http://twitter.com/search?q=%23starlink",
#     "name": "#starlink",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": null,
#     "query": "%23BucksIn7",
#     "url": "http://twitter.com/search?q=%23BucksIn7",
#     "name": "#BucksIn7",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": null,
#     "query": "%23HustleAndSoul",
#     "url": "http://twitter.com/search?q=%23HustleAndSoul",
#     "name": "#HustleAndSoul",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": null,
#     "query": "%23SpaceX",
#     "url": "http://twitter.com/search?q=%23SpaceX",
#     "name": "#SpaceX",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": 11118,
#     "query": "%23SaveSocialBlade",
#     "url": "http://twitter.com/search?q=%23SaveSocialBlade",
#     "name": "#SaveSocialBlade",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": 13133,
#     "query": "%23LipsDontLie",
#     "url": "http://twitter.com/search?q=%23LipsDontLie",
#     "name": "#LipsDontLie",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": null,
#     "query": "%23RaptorsVsBucks",
#     "url": "http://twitter.com/search?q=%23RaptorsVsBucks",
#     "name": "#RaptorsVsBucks",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": null,
#     "query": "%23BucksvsRaptors",
#     "url": "http://twitter.com/search?q=%23BucksvsRaptors",
#     "name": "#BucksvsRaptors",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": null,
#     "query": "%23BTS20MPARTY",
#     "url": "http://twitter.com/search?q=%23BTS20MPARTY",
#     "name": "#BTS20MPARTY",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": null,
#     "query": "%23CrossMe",
#     "url": "http://twitter.com/search?q=%23CrossMe",
#     "name": "#CrossMe",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": null,
#     "query": "%23insteadofgoodbye",
#     "url": "http://twitter.com/search?q=%23insteadofgoodbye",
#     "name": "#insteadofgoodbye",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": null,
#     "query": "%23DoubleShotAtLove",
#     "url": "http://twitter.com/search?q=%23DoubleShotAtLove",
#     "name": "#DoubleShotAtLove",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": null,
#     "query": "%23Falcon9",
#     "url": "http://twitter.com/search?q=%23Falcon9",
#     "name": "#Falcon9",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": null,
#     "query": "%23SHADOWBRINGERS",
#     "url": "http://twitter.com/search?q=%23SHADOWBRINGERS",
#     "name": "#SHADOWBRINGERS",
#     "promoted_content": null
#    },
#    {
#     "tweet_volume": null,
#     "query": "%23Elementary",
#     "url": "http://twitter.com/search?q=%23Elementary",
#     "name": "#Elementary",
#     "promoted_content": null
#    }
#   ],
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ],
#   "created_at": "2019-05-24T06:01:53Z",
#   "as_of": "2019-05-24T06:08:35Z"
#  }
# ]

# %% [markdown]
# ## Example 4. Computing the intersection of two sets of trends

# %%
trends_set = {}
trends_set['world'] = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

trends_set['us'] = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

trends_set['san diego'] = set([trend['name'] 
                     for trend in local_trends[0]['trends']])

# %%
#trends_set['world']
#trends_set['us']
#trends_set['san diego']

# %%
for loc in ['world','us','san diego']:
    print(('-'*10,loc))
    print((','.join(trends_set[loc])))
# Out:
# ('----------', 'world')
# #HayırlıCumalar,#PhasesEP,#자캐는_체육대회에서_무슨_종목,#ExNaMTV,#HampaDelPeriodismo,#ChatpataElection,適応障害,#SaanNapupuntaAngPeraMo,#TORvsMIL,#ShowtimeMaCOOLay,ベンチマーク,Bucks in 7,#あなたの中身は何か,#LipsDontLie,#ทฤษฎีจีบเธอ,Gignac,#LaPiñaDeLaDiscordia,#THRBelumTerlihat,João Pedro,#يوم_الجمعه,#TNRejectsBJP,#PowerCoupleMulheres,#LoveBTS20M,#LosCruzados,#MeTeníaChato,ロスガル,#WeTheNorh,#BTS20M,Aaron Rodgers,#mykpopcareer,#yağmur,#RaptorsVsBucks,#mybtsenergy,#CongratulationsMheshimiwa,#KemenanganUntukSemua,#PactoDeSangre,#İtirazımızVar,#FikrimYok,#ياعلي,Fred VanVleet,#20MillionReasons,#ProtestoEdiyorum,ヴィエラ,#اختيار_التخصص_الجامعي,#PromediosEnTyCSports,#WeirdQuestionsForGoogle,#JumatBerkah,#SextaDetremuraSDV,#YoSoyAnimal,#مسابقه_المربع_نت١٩
# ('----------', 'us')
# #SpaceX,#PhasesEP,Money Man,Dionne,#EscapeFromNewYork,#Elementary,#DoubleShotAtLove,Raptors in 6,Pusha T,#TORvsMIL,#StableGenius,Beast Coast,#SaveSocialBlade,Bucks in 7,#LipsDontLie,Steve Lacy,#CriticalRole,#SHADOWBRINGERS,#BTS20MPARTY,Gucci Mane,#LoveBTS20M,Chris Webber,#insteadofgoodbye,#Falcon9,Aaron Rodgers,Lucas Giolito,#HustleAndSoul,#43VAHEARTLESS,The London,Van Vleet,#4REAL4REAL,#mybtsenergy,#ProjectRunway,#RaptorsVsBucks,Mallory Edens,Ross Bjork,Marv Albert,#starlink,#BucksIn7,#UnlikelyReasonsToMoveOut,Fred VanVleet,#20MillionReasons,#WeirdQuestionsForGoogle,#CrossMe,Viera,#WhenIAmOutWithFriends,Krassensteins,Eyes Off You,#BucksvsRaptors,Moneybagg
# ('----------', 'san diego')
# Assange,#WorldTurtleDay,#SpaceX,#PhasesEP,Money Man,#EscapeFromNewYork,Bucks,Aladdin,#DoubleShotAtLove,#StableGenius,Pusha T,#TORvsMIL,#SaveSocialBlade,Beast Coast,#LipsDontLie,Steve Lacy,#CriticalRole,#SHADOWBRINGERS,#BTS20MPARTY,Gucci Mane,#LoveBTS20M,Chris Webber,#insteadofgoodbye,#Falcon9,Aaron Rodgers,Lucas Giolito,#HustleAndSoul,Drake,#43VAHEARTLESS,The London,Van Vleet,#4REAL4REAL,#mybtsenergy,#ProjectRunway,Mallory Edens,Ross Bjork,Marv Albert,#starlink,Raptors,#UnlikelyReasonsToMoveOut,#energy,Fred VanVleet,#20MillionReasons,#WeirdQuestionsForGoogle,#CrossMe,Viera,#WhenIAmOutWithFriends,Krassensteins,Eyes Off You,Moneybagg

# %%
print(( '='*10,'intersection of world and us'))
print((trends_set['world'].intersection(trends_set['us'])))

print(('='*10,'intersection of us and san-diego'))
print((trends_set['san diego'].intersection(trends_set['us'])))
# Out:
# ('==========', 'intersection of world and us')
# {'Aaron Rodgers', 'Fred VanVleet', '#20MillionReasons', '#WeirdQuestionsForGoogle', '#PhasesEP', '#RaptorsVsBucks', '#mybtsenergy', '#LoveBTS20M', '#TORvsMIL', 'Bucks in 7', '#LipsDontLie'}
# ('==========', 'intersection of us and san-diego')
# {'#SpaceX', '#PhasesEP', 'Money Man', '#EscapeFromNewYork', '#DoubleShotAtLove', '#StableGenius', 'Pusha T', '#TORvsMIL', '#SaveSocialBlade', 'Beast Coast', '#LipsDontLie', 'Steve Lacy', '#CriticalRole', '#SHADOWBRINGERS', '#BTS20MPARTY', 'Gucci Mane', '#LoveBTS20M', 'Chris Webber', '#Falcon9', '#insteadofgoodbye', 'Aaron Rodgers', 'Lucas Giolito', '#HustleAndSoul', '#43VAHEARTLESS', 'The London', 'Van Vleet', '#4REAL4REAL', '#mybtsenergy', '#ProjectRunway', 'Mallory Edens', 'Ross Bjork', 'Marv Albert', '#starlink', '#UnlikelyReasonsToMoveOut', 'Fred VanVleet', '#20MillionReasons', '#WeirdQuestionsForGoogle', '#CrossMe', 'Viera', '#WhenIAmOutWithFriends', 'Krassensteins', 'Eyes Off You', 'Moneybagg'}

# %% [markdown]
# ## Example 5. Collecting search results

# %% [markdown]
# Set the variable `q` to a trending topic,
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter

# %%
q = '#MTVAwards' 

number = 100
#number = 2

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=number)
print(search_results)
statuses = search_results['statuses']
# Out:
# {'statuses': [{'created_at': 'Fri May 24 08:44:29 +0000 2019', 'lang': 'en', 'in_reply_to_user_id': None, 'in_reply_to_status_id_str': None, 'possibly_sensitive': False, 'user': {'screen_name': 'MTVAfrica', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif', 'listed_count': 155, 'lang': 'en', 'translator_type': 'regular', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/981129505246011392/TitPqE8r_normal.jpg', 'default_profile_image': False, 'profile_background_tile': True, 'statuses_count': 31611, 'profile_sidebar_fill_color': '000000', 'profile_use_background_image': True, 'profile_sidebar_border_color': '000000', 'created_at': 'Wed Jun 13 15:59:55 +0000 2012', 'verified': True, 'following': False, 'default_profile': False, 'protected': False, 'is_translation_enabled': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/981129505246011392/TitPqE8r_normal.jpg', 'notifications': False, 'favourites_count': 2543, 'time_zone': None, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/607408722/1556133171', 'profile_background_color': '131516', 'id': 607408722, 'name': 'MTVAfrica', 'follow_request_sent': False, 'geo_enabled': True, 'followers_count': 171350, 'location': 'Africa', 'has_extended_profile': False, 'entities': {'description': {'urls': []}, 'url': {'urls': [{'display_url': 'MTV.co.za', 'expanded_url': 'http://MTV.co.za', 'indices': [0, 23], 'url': 'https://t.co/9da5SPzHp1'}]}}, 'is_translator': False, 'profile_text_color': '000000', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif', 'contributors_enabled': False, 'description': 'The official Twitter account for MTV Africa - entertainment, lifestyle, music + more! IG:@mtvza Snapchat:MTV Africa', 'id_str': '607408722', 'profile_link_color': '009999', 'friends_count': 50, 'utc_offset': None, 'url': 'https://t.co/9da5SPzHp1'}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'in_reply_to_status_id': None, 'coordinates': None, 'in_reply_to_screen_name': None, 'retweet_count': 0, 'favorited': False, 'retweeted': False, 'in_reply_to_user_id_str': None, 'id': 1131843396656672769, 'favorite_count': 4, 'truncated': True, 'entities': {'symbols': [], 'hashtags': [], 'user_mentions': [], 'urls': [{'display_url': 'vote.mtv.com', 'expanded_url': 'http://vote.mtv.com', 'indices': [64, 87], 'url': 'https://t.co/UTD4ICNzno'}, {'display_url': 'twitter.com/i/web/status/1…', 'expanded_url': 'https://twitter.com/i/web/status/1131843396656672769', 'indices': [120, 143], 'url': 'https://t.co/3Hfy3yl9NF'}]}, 'text': "Who's got your vote for BEST FIGHT? 👊 Hit 'em with some love at https://t.co/UTD4ICNzno &amp; see who wins at the 2019… https://t.co/3Hfy3yl9NF", 'is_quote_status': False, 'id_str': '1131843396656672769', 'place': None, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'contributors': None, 'geo': None}, {'created_at': 'Fri May 24 08:44:02 +0000 2019', 'lang': 'en', 'in_reply_to_user_id': None, 'in_reply_to_status_id_str': None, 'possibly_sensitive': False, 'favorite_count': 0, 'user': {'screen_name': 'Von_T_Burger', 'profile_background_image_url': None, 'listed_count': 0, 'lang': 'en', 'translator_type': 'none', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1127173271487516673/-2AOIfps_normal.jpg', 'default_profile_image': False, 'profile_background_tile': False, 'statuses_count': 1429, 'profile_sidebar_fill_color': 'DDEEF6', 'profile_use_background_image': True, 'profile_sidebar_border_color': 'C0DEED', 'created_at': 'Fri Nov 03 08:39:39 +0000 2017', 'verified': False, 'following': False, 'default_profile': True, 'protected': False, 'is_translation_enabled': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1127173271487516673/-2AOIfps_normal.jpg', 'notifications': False, 'favourites_count': 17436, 'time_zone': None, 'profile_banner_url': 'https://pbs.twimg.com/profile_banne ...

# %%
print(statuses[0].keys())
print(search_results.keys())
print(search_results['search_metadata'])
# Out:
# dict_keys(['created_at', 'lang', 'in_reply_to_user_id', 'in_reply_to_status_id_str', 'possibly_sensitive', 'user', 'metadata', 'in_reply_to_status_id', 'coordinates', 'in_reply_to_screen_name', 'retweet_count', 'favorited', 'retweeted', 'in_reply_to_user_id_str', 'id', 'favorite_count', 'truncated', 'entities', 'text', 'is_quote_status', 'id_str', 'place', 'source', 'contributors', 'geo'])
# dict_keys(['statuses', 'search_metadata'])
# {'since_id': 0, 'refresh_url': '?since_id=1131843396656672769&q=%23MTVAwards&include_entities=1', 'count': 100, 'since_id_str': '0', 'max_id_str': '1131843396656672769', 'completed_in': 0.118, 'max_id': 1131843396656672769, 'next_results': '?max_id=1131741330969960447&q=%23MTVAwards&count=100&include_entities=1', 'query': '%23MTVAwards'}

# %%
print(len(statuses))
#print(statuses)
statuses[0]['text']
# Out:
# 70
# "Who's got your vote for BEST FIGHT? 👊 Hit 'em with some love at https://t.co/UTD4ICNzno &amp; see who wins at the 2019… https://t.co/3Hfy3yl9NF"

# %% [markdown]
# Twitter often returns duplicate results, we can filter them out checking for duplicate texts:

# %%
all_text = []
filtered_statuses = []
for s in statuses:
    if not s["text"] in all_text:
        filtered_statuses.append(s)
        all_text.append(s["text"])
statuses = filtered_statuses

# %%
len(statuses)
# Out:
# 44

# %%
[s['text'] for s in search_results['statuses']]
# Out:
# ["Who's got your vote for BEST FIGHT? 👊 Hit 'em with some love at https://t.co/UTD4ICNzno &amp; see who wins at the 2019… https://t.co/3Hfy3yl9NF",
#  "RT @MTV: #MTVAwards performer @MartinGarrix's video for #SummerDays is  sweaty daydream: https://t.co/jA1VlsWJ35 https://t.co/4tAYwe0huG",
#  "RT @MTVAwards: 🎬And the nominees for BEST Performance in a Movie are...🎬\n\nDon't forget to vote for the #MTVAwards at https://t.co/srdtfvy53…",
#  'RT @MTVAwards: 💥Vote NOW  for BEST HERO at the 2019 #MTVAwards at https://t.co/srdtfvPGrL 💥\n\nWho are you rooting for? See if they win Monda…',
#  '✨YOUR BEST DOCUMENTARY NOMINEES✨ Vote now for your fave to win at https://t.co/UTD4ICNzno ＋ watch the #MTVAwards on… https://t.co/1gOiyBXcgh',
#  'RT @MTV: Throwing it back to when the @13ReasonsWhy cast presented the @Stranger_Things cast with their Golden Popcorn at the 2017 #MTVAwar…',
#  'And your vote for Breakthrough Performance goes to ____? ⭐ Vote NOW for your pick at https://t.co/UTD4ICNzno ＋ tune… https://t.co/jQ5DrnUXhh',
#  'RT @MTVAwards: @GagaMediaDotNet hi!!!!! be sure to vote for the #MTVAwards every day at https://t.co/srdtfvPGrL ❤️\n\nGaga is nominated for B…',
#  'Presenting the 2019 #MTVAwards performers... ✨@lizzo and @MartinGarrix featuring @macklemore and @PatrickStump of… https://t.co/xxk2IHzYlh',
#  "Who's your pick for 💋Best Kiss?💋 Show them some love at https://t.co/UTD4ICNzno and see if they take home an… https://t.co/oVigu4iKhq",
#  "RT @MTV: #MTVAwards performer @MartinGarrix's video for #SummerDays is  sweaty daydream: https://t.co/jA1VlsWJ35 https://t.co/4tAYwe0huG",
#  'RT @MTVAwards: @gagamonster96 hey!!! just wanted to remind you that you can vote EVERY DAY for the #MTVAwards at https://t.co/srdtfvPGrL 💛…',
#  "RT @MTVAwards: @brielarson hi @captainmarvel!! you've been nominated for Best Hero AND Best Fight at the 2019 #MTVAwards 💫 vote now at http…",
#  '@MTVAwards The Biggest Indie movie on #YouTube over 3.8 Million views but no Nominations geesh! https://t.co/v0tJtvL06r #YouTube #Mtvawards',
#  'RT @MTVAwards: #MTVAwards host and 2x nominee @ZacharyLevi has a message for all of you:\n\n🗣VOTE NOW AT https://t.co/lc9FYSy4FC🗣 https://t.c…',
#  "RT @MTV: #MTVAwards performer @MartinGarrix's video for #SummerDays is  sweaty daydream: https://t.co/jA1VlsWJ35 https://t.co/4tAYwe0huG",
#  'RT @vmas: Did you hear @ladygaga is nominated for Best Performance in a Movie for @starisbornmovie at the @MTVAwards? 🌟\n\nHead to https://t.…',
#  'RT @deriamedia: 🌟CALLING ALL LITTLE MONSTERS 🌟\n\nDid you hear LadyGaga is nominated for Best Performance in a Movie at the 2019 MTVAwards? H…',
#  'Throwing it back to when the 13ReasonsWhy cast presented the Stranger_Things cast with their Golden Popcorn at the… https://t.co/XKPlNuiLP2',
#  "RT @MTVNEWS: #AvengersEndgame is up for 4 awards at this year's #MTVAwards 🍿 Watch your @Avengers faves play a friendly game of cast superl…",
#  'RT @MTVNEWS: .@MartinGarrix, @macklemore, and @PatrickStump will also perform #SummerDays – their new seasonal bop – at this year’s #MTVAwa…',
#  'This is awesome! @BTS_twt 💜 \n\nPlease keep streaming #BoyWithLuv \n\nAnd vote\n\n#MTVLAINSTAGLJUNGKOOK… https://t.co/nSvldshsdu',
#  'RT @Lupita_Nyongo: Thank you @MTV for my Best Performance and Best Villain #UsMovie nominations, and for recognizing the film in the Best M…',
#  "RT @MTV: #MTVAwards performer @MartinGarrix's video for #SummerDays is  sweaty daydream: https://t.co/jA1VlsWJ35 https://t.co/4tAYwe0huG",
#  "RT @MTVAwards: 🎬And the nominees for BEST Performance in a Movie are...🎬\n\nDon't forget to vote for the #MTVAwards at https://t.co/srdtfvy53…",
#  'RT @MTVAwards: @alexhonnold you’ve been nominated as Best Real Life Hero at the 2019 #MTVAwards for #FreeSolo! Vote now at https://t.co/srd…',
#  "RT @MTV: The Riverdale cast emphasize one of the main messages of the #MTVAwards: categories don't need to be gendered. ❤️️ Catch them toni…",
#  "RT @MTV: @CaptainAmerica @Avengers Congrats on your #MTVAwards nomination! There's only one week left to vote: https://t.co/hEh9YTg5A1 💥👊 h…",
#  'RT @MTVAwards: #MTVAwards host and 2x nominee @ZacharyLevi has a message for all of you:\n\n🗣VOTE NOW AT https://t.co/lc9FYSy4FC🗣 https://t.c…',
#  'RT @MTV: Throwing it back to when the @13ReasonsWhy cast presented the @Stranger_Things cast with their Golden Popcorn at the 2017 #MTVAwar…',
#  'RT @MTVAwards: 💥Vote NOW  for BEST HERO at the 2019 #MTVAwards at https://t.co/srdtfvPGrL 💥\n\nWho are you rooting for? See if they win Monda…',
#  'RT @MTVNEWS: .@MartinGarrix, @macklemore, and @PatrickStump will also perform #SummerDays – their new seasonal bop – at this year’s #MTVAwa…',
#  'RT @MTVAwards: 📺Here are the nominees for Best Performance in a Show 📺\n\nVote for your fave at https://t.co/srdtfvPGrL and watch the #MTVAwa…',
#  'RT @MTVAwards: 👊THE BEST FIGHT NOMINEES👊\n\nVote, vote, vote at https://t.co/srdtfvPGrL and see who wins Monday, June 17 at 9p on @MTV #MTVAw…',
#  "RT @MTVAwards: 🎬And the nominees for BEST Performance in a Movie are...🎬\n\nDon't forget to vote for the #MTVAwards at https://t.co/srdtfvy53…",
#  "RT @MTVNEWS: #AvengersEndgame is up for 4 awards at this year's #MTVAwards 🍿 Watch your @Avengers faves play a friendly game of cast superl…",
#  "RT @RuPaulsDragRace: CALL HER MOTHER 👑🏁 VOTE now for Mama @Rupaul as 'Best Host' for the 2019 #MTVAwards ➡️https://t.co/PB1FvTF6hF https://…",
#  'RT @MTVAwards: I LOVE YOU TONY STARK. #MTVAwards https://t.co/qo8UazcN5s',
#  'RT @MTV: Throwing it back to when the @13ReasonsWhy cast presented the @Stranger_Things cast with their Golden Popcorn at the 2017 #MTVAwar…',
#  'RT @MTVAwards: #MTVAwards host and 2x nominee @ZacharyLevi has a message for all of you:\n\n🗣VOTE NOW AT https://t.co/lc9FYSy4FC🗣 https://t.c…',
#  "RT @MTVNEWS: #AvengersEndgame is up for 4 awards at this year's #MTVAwards 🍿 Watch your @Avengers faves play a friendly game of cast superl…",
#  "RT @MTV: #MTVAwards performer @MartinGarrix's video for #SummerDays is  sweaty daydream: https://t.co/jA1VlsWJ35 https://t.co/4tAYwe0huG",
#  'RT @HumeDeLeto: Quiero ver el mundo arder..... 👀😻\n@BTS_twt \n#MTVLAKPOPBTS #MTVLAFANDOMBTSARMY #MTVLAINSTAGLJUNGKOOK \n#MTVAwards\n#PremiosMTV…',
#  "I just finished DM with @MTVAwards again. So interesting!  I can't wait to watch the show. #AvengersEndgame #MTVAwards",
#  "RT @MTV: #MTVAwards performer @MartinGarrix's video for #SummerDays is  sweaty daydream: https://t.co/jA1VlsWJ35 https://t.co/4tAYwe0huG",
#  "RT @MTV: @danjlevy @SchittsCreek Hey there! Congrats on your #MTVAwards nomination! There's only one week left to vote: https://t.co/hEh9YS…",
#  "RT @MTVAwards: The #MTVAwards noms got kings &amp; queens &amp; all-things fierce 💥 ⚔️👠\n\nBut most importantly, we've got YOU!\n\nIt's up to YOU to de…",
#  "RT @MTV: #MTVAwards performer @MartinGarrix's video for #SummerDays is  sweaty daydream: https://t.co/jA1VlsWJ35 https://t.co/4tAYwe0huG",
#  "RT @RuPaulsDragRace: CALL HER MOTHER 👑🏁 VOTE now for Mama @Rupaul as 'Best Host' for the 2019 #MTVAwards ➡️https://t.co/PB1FvTF6hF https://…",
#  'RT @MTVAwards: Have you voted yet for BEST MOVIE at the 2019 #MTVAwards?\n\n#AvengersEndgame &amp; #BlacKkKlansman &amp; #SpiderVerse &amp; #ToAllTheBoys…',
#  'RT @MTVAwards: #MTVAwards host and 2x nominee @ZacharyLevi has a message for all of you:\n\n🗣VOTE NOW AT https://t.co/lc9FYSy4FC🗣 https://t.c…',
#  'RT @HumeDeLeto: What may i say? No? \n\n@BTS_twt \n#MTVLAKPOPBTS #MTVLAFANDOMBTSARMY #MTVLAINSTAGLJUNGKOOK \n#MTVAwards\n#PremiosMTVMIAW \n#BTSen…',
#  "RT @MTV: #MTVAwards performer @MartinGarrix's video for #SummerDays is  sweaty daydream: https://t.co/jA1VlsWJ35 https://t.co/4tAYwe0huG",
#  "RT @MTV: #MTVAwards performer @MartinGarrix's video for #SummerDays is  sweaty daydream: https://t.co/jA1VlsWJ35 https://t.co/4tAYwe0huG",
#  'RT @bestsofrdj: .@RobertDowneyJr has been nominated for "Best Hero" at #MTVAwards 2019 🎉 you can vote here : https://t.co/NWH16f13Yi',
#  'RT @MTVAwards: #MTVAwards host and 2x nominee @ZacharyLevi has a message for all of you:\n\n🗣VOTE NOW AT https://t.co/lc9FYSy4FC🗣 https://t.c…',
#  'What may i say? No? \n\n@BTS_twt \n#MTVLAKPOPBTS #MTVLAFANDOMBTSARMY #MTVLAINSTAGLJUNGKOOK \n#MTVAwards\n#PremiosMTVMIAW… https://t.co/Ov4sjlwbtm',
#  "RT @MTV: #MTVAwards performer @MartinGarrix's video for #SummerDays is  sweaty daydream: https://t.co/jA1VlsWJ35 https://t.co/4tAYwe0huG",
#  '@NevSchulman my t.v. has a lot of catching up to do for the very awesome episodes of catfish #MTVAwards #Trending #Verdict2019WithNews18',
#  'RT @MTV: Throwing it back to when the @13ReasonsWhy cast presented the @Stranger_Things cast with their Golden Popcorn at the 2017 #MTVAwar…',
#  '#mtv #mtvthechallenge #mtvcribs #mtvmovieawards #mtvacashore #mtvla #mtvawards #mtvaytobr #mtvwildnout… https://t.co/2OWVfGPOfV',
#  'RT @MTV: Throwing it back to when the @13ReasonsWhy cast presented the @Stranger_Things cast with their Golden Popcorn at the 2017 #MTVAwar…',
#  "RT @SchittsCreek: Word on the street is if you're in the USA you can vote once every twelve hours... ➡️ https://t.co/mCxeZKBVm1 ⬅️\n\n#Schitt…",
#  'Olivier Farwell - Cross The Line -- Out May 30th, 2019 #olivierfarwell #MTVAwards #crosstheline #summerhit… https://t.co/ioghEWLFod',
#  "RT @MTV: #MTVAwards performer @MartinGarrix's video for #SummerDays is  sweaty daydream: https://t.co/jA1VlsWJ35 https://t.co/4tAYwe0huG",
#  "Martin Garrix, Macklemore, And Patrick Stump's 'Summer Days' Video Is A Sweaty Daydream https://t.co/tJPxnesChM #mtvawards",
#  'Hello... Chicos... Se vende se vende todo amiguillos 🎵🤘\n@BTS_twt \n#MTVLAKPOPBTS #MTVLAFANDOMBTSARMY… https://t.co/X52N8FkdGb',
#  "RT @NabillaNugr: Man in a suit of armor, take that off, what is he? 'Best Hero' winner.\n\n@RobertDowneyJr 'I am #Ironman' on @MTVAwards FTW!…",
#  '.@MartinGarrix, @macklemore, and @PatrickStump will also perform #SummerDays – their new seasonal bop – at this yea… https://t.co/QiXQWdhbF1',
#  "RT @MTV: #MTVAwards performer @MartinGarrix's video for #SummerDays is  sweaty daydream: https://t.co/jA1VlsWJ35 https://t.co/4tAYwe0huG"]

# %%
# Show one sample search result by slicing the list...
print(json.dumps(statuses[0], indent=1))
# Out:
# {
#  "created_at": "Fri May 24 08:44:29 +0000 2019",
#  "lang": "en",
#  "in_reply_to_user_id": null,
#  "in_reply_to_status_id_str": null,
#  "possibly_sensitive": false,
#  "user": {
#   "screen_name": "MTVAfrica",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
#   "listed_count": 155,
#   "lang": "en",
#   "translator_type": "regular",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/981129505246011392/TitPqE8r_normal.jpg",
#   "default_profile_image": false,
#   "profile_background_tile": true,
#   "statuses_count": 31611,
#   "profile_sidebar_fill_color": "000000",
#   "profile_use_background_image": true,
#   "profile_sidebar_border_color": "000000",
#   "created_at": "Wed Jun 13 15:59:55 +0000 2012",
#   "verified": true,
#   "following": false,
#   "default_profile": false,
#   "protected": false,
#   "is_translation_enabled": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/981129505246011392/TitPqE8r_normal.jpg",
#   "notifications": false,
#   "favourites_count": 2543,
#   "time_zone": null,
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/607408722/1556133171",
#   "profile_background_color": "131516",
#   "id": 607408722,
#   "name": "MTVAfrica",
#   "follow_request_sent": false,
#   "geo_enabled": true,
#   "followers_count": 171350,
#   "location": "Africa",
#   "has_extended_profile": false,
#   "entities": {
#    "description": {
#     "urls": []
#    },
#    "url": {
#     "urls": [
#      {
#       "display_url": "MTV.co.za",
#       "expanded_url": "http://MTV.co.za",
#       "indices": [
#        0,
#        23
#       ],
#       "url": "https://t.co/9da5SPzHp1"
#      }
#     ]
#    }
#   },
#   "is_translator": false,
#   "profile_text_color": "000000",
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
#   "contributors_enabled": false,
#   "description": "The official Twitter account for MTV Africa - entertainment, lifestyle, music + more! IG:@mtvza Snapchat:MTV Africa",
#   "id_str": "607408722",
#   "profile_link_color": "009999",
#   "friends_count": 50,
#   "utc_offset": null,
#   "url": "https://t.co/9da5SPzHp1"
#  },
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  },
#  "in_reply_to_status_id": null,
#  "coordinates": null,
#  "in_reply_to_screen_name": null,
#  "retweet_count": 0,
#  "favorited": false,
#  "retweeted": false,
#  "in_reply_to_user_id_str": null,
#  "id": 1131843396656672769,
#  "favorite_count": 4,
#  "truncated": true,
#  "entities": {
#   "symbols": [],
#   "hashtags": [],
#   "user_mentions": [],
#   "urls": [
#    {
#     "display_url": "vote.mtv.com",
#     "expanded_url": "http://vote.mtv.com",
#     "indices": [
#      64,
#      87
#     ],
#     "url": "https://t.co/UTD4ICNzno"
#    },
#    {
#     "display_url": "twitter.com/i/web/status/1\u2026",
#     "expanded_url": "https://twitter.com/i/web/status/1131843396656672769",
#     "indices": [
#      120,
#      143
#     ],
#     "url": "https://t.co/3Hfy3yl9NF"
#    }
#   ]
#  },
#  "text": "Who's got your vote for BEST FIGHT? \ud83d\udc4a Hit 'em with some love at https://t.co/UTD4ICNzno &amp; see who wins at the 2019\u2026 https://t.co/3Hfy3yl9NF",
#  "is_quote_status": false,
#  "id_str": "1131843396656672769",
#  "place": null,
#  "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#  "contributors": null,
#  "geo": null
# }

# %%
# The result of the list comprehension is a list with only one element that
# can be accessed by its index and set to the variable t
t = statuses[0]
#[ status for status in statuses 
#          if status['id'] == 316948241264549888 ][0]

# Explore the variable t to get familiarized with the data structure...

print(t['retweet_count'])
print(t['retweeted'])
# Out:
# 0
# False

# %%
t.keys()
# Out:
# dict_keys(['created_at', 'lang', 'in_reply_to_user_id', 'in_reply_to_status_id_str', 'possibly_sensitive', 'user', 'metadata', 'in_reply_to_status_id', 'coordinates', 'in_reply_to_screen_name', 'retweet_count', 'favorited', 'retweeted', 'in_reply_to_user_id_str', 'id', 'favorite_count', 'truncated', 'entities', 'text', 'is_quote_status', 'id_str', 'place', 'source', 'contributors', 'geo'])

# %% [markdown]
# ## Example 6. Extracting text, screen names, and hashtags from tweets

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# %%
# Explore the first 5 items for each...

print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(screen_names[0:5], indent=1)) 
print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))
# Out:
# [
#  "Who's got your vote for BEST FIGHT? \ud83d\udc4a Hit 'em with some love at https://t.co/UTD4ICNzno &amp; see who wins at the 2019\u2026 https://t.co/3Hfy3yl9NF",
#  "RT @MTV: #MTVAwards performer @MartinGarrix's video for #SummerDays is  sweaty daydream: https://t.co/jA1VlsWJ35 https://t.co/4tAYwe0huG",
#  "RT @MTVAwards: \ud83c\udfacAnd the nominees for BEST Performance in a Movie are...\ud83c\udfac\n\nDon't forget to vote for the #MTVAwards at https://t.co/srdtfvy53\u2026",
#  "RT @MTVAwards: \ud83d\udca5Vote NOW  for BEST HERO at the 2019 #MTVAwards at https://t.co/srdtfvPGrL \ud83d\udca5\n\nWho are you rooting for? See if they win Monda\u2026",
#  "\u2728YOUR BEST DOCUMENTARY NOMINEES\u2728 Vote now for your fave to win at https://t.co/UTD4ICNzno \uff0b watch the #MTVAwards on\u2026 https://t.co/1gOiyBXcgh"
# ]
# [
#  "MTV",
#  "MartinGarrix",
#  "MTVAwards",
#  "MTVAwards",
#  "MTV"
# ]
# [
#  "MTVAwards",
#  "SummerDays",
#  "MTVAwards",
#  "MTVAwards",
#  "MTVAwards"
# ]
# [
#  "Who's",
#  "got",
#  "your",
#  "vote",
#  "for"
# ]

# %% [markdown]
# ## Example 7. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print(c.most_common()[:10]) # top 10
    print()

# %% [markdown]
# ## Example 8. Create a prettyprint function to display tuples in a nice tabular format

# %%
def prettyprint_counts(label, list_of_tuples):
    print("\n{:^20} | {:^6}".format(label, "Count"))
    print("*"*40)
    for k,v in list_of_tuples:
        print("{:20} | {:>6}".format(k,v))

# %%
for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    
    c = Counter(data)
    prettyprint_counts(label, c.most_common()[:10])

# %% [markdown]
# ## Example 9. Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text'].replace("\n","\\")) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status
           ]

# %% [markdown]
# We can build another `prettyprint` function to print entire tweets with their retweet count.
#
# We also want to split the text of the tweet in up to 3 lines, if needed.

# %%
row_template = "{:^7} | {:^15} | {:50}"
def prettyprint_tweets(list_of_tuples):
    print()
    print(row_template.format("Count", "Screen Name", "Text"))
    print("*"*60)
    for count, screen_name, text in list_of_tuples:
        print(row_template.format(count, screen_name, text[:50]))
        if len(text) > 50:
            print(row_template.format("", "", text[50:100]))
            if len(text) > 100:
                print(row_template.format("", "", text[100:]))

# %%
# Slice off the first 5 from the sorted results and display each item in the tuple

prettyprint_tweets(sorted(retweets, reverse=True)[:10])
